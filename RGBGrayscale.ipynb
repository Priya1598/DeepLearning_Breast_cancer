# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya1598/DeepLearning_Breast_cancer/blob/main/RGBGrayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##getimage using web get

# %%
# !wget 'https://ichef.bbci.co.uk/ace/standard/2560/cpsprodpb/b4d2/live/c39db240-42ae-11f0-88e1-3f1b11853089.jpg'
# Out:
# --2025-10-16 12:20:52--  https://ichef.bbci.co.uk/ace/standard/2560/cpsprodpb/b4d2/live/c39db240-42ae-11f0-88e1-3f1b11853089.jpg
# Resolving ichef.bbci.co.uk (ichef.bbci.co.uk)... 23.204.249.57, 2600:1406:5600:685::f33, 2600:1406:5600:686::f33, ...
# Connecting to ichef.bbci.co.uk (ichef.bbci.co.uk)|23.204.249.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 355743 (347K) [image/jpeg]
# Saving to: ‘c39db240-42ae-11f0-88e1-3f1b11853089.jpg’
#
# c39db240-42ae-11f0- 100%[===================>] 347.41K  --.-KB/s    in 0.04s
#
# 2025-10-16 12:20:52 (9.34 MB/s) - ‘c39db240-42ae-11f0-88e1-3f1b11853089.jpg’ saved [355743/355743]

# %%
##Libraries used for image preprocessing

# %%
#matplotlib.image
# pillow
# opencv(cv2)

# %%
# !pip install Pillow
# !pip install opencv-python

# %%
import matplotlib.image as mpimg
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/Catimage.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
(img.shape)   ## gray scale image 0 to 255 0 black 255 white
##RGB image which as 3 channel red green and blue. red has high intensity green has less intensity than red and blue has less intensity
# Out:
# (1440, 2560, 3)

# %%
print(img)
# Out:
# [[[221 216 212]
#   [220 215 211]
#   [220 215 211]
#   ...
#   [217 208 203]
#   [217 208 203]
#   [217 208 203]]
#
#  [[221 216 212]
#   [220 215 211]
#   [220 215 211]
#   ...
#   [217 208 203]
#   [217 208 203]
#   [217 208 203]]
#
#  [[221 216 212]
#   [221 216 212]
#   [220 215 211]
#   ...
#   [217 208 203]
#   [217 208 203]
#   [217 208 203]]
#
#  ...
#
#  [[200 195 191]
#   [199 194 190]
#   [198 193 189]
#   ...
#   [236 234 235]
#   [235 233 234]
#   [236 234 235]]
#
#  [[197 192 188]
#   [196 191 187]
#   [195 190 186]
#   ...
#   [237 235 236]
#   [236 234 235]
#   [237 235 236]]
#
#  [[192 187 183]
#   [192 187 183]
#   [191 186 182]
#   ...
#   [237 235 236]
#   [237 235 236]
#   [238 236 237]]]

# %%
# Displaying the image using numpy array

img_plot=plt.imshow(img)
plt.show()

# %% [markdown]
# # Resizing the image using pillow library

# %%
from PIL import Image

# %%
img=Image.open('/content/Catimage.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('Catimage_resized.jpg')

# %%
img_res=mpimg.imread('/content/Catimage_resized.jpg')
img_res_plot=plt.imshow(img)

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
print(img_res)
# Out:
# [[[221 216 212]
#   [221 216 212]
#   [221 216 212]
#   ...
#   [219 210 205]
#   [219 210 205]
#   [219 210 205]]
#
#  [[221 216 212]
#   [221 216 212]
#   [220 215 211]
#   ...
#   [219 210 205]
#   [219 210 205]
#   [219 210 205]]
#
#  [[221 216 212]
#   [220 215 211]
#   [220 215 211]
#   ...
#   [219 210 205]
#   [219 210 205]
#   [219 210 205]]
#
#  ...
#
#  [[192 187 181]
#   [174 169 163]
#   [137 132 126]
#   ...
#   [212 210 211]
#   [226 224 225]
#   [221 219 220]]
#
#  [[216 211 205]
#   [193 188 182]
#   [166 161 155]
#   ...
#   [190 188 189]
#   [212 210 211]
#   [230 228 229]]
#
#  [[202 197 191]
#   [178 173 167]
#   [174 169 163]
#   ...
#   [176 174 175]
#   [198 196 197]
#   [234 232 233]]]

# %% [markdown]
# Converting RBG image to Gray Scale Inage using Open CV

# %%
import cv2

# %%
img=cv2.imread('/content/Catimage.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
(img.shape)
# Out:
# (1440, 2560, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
print(grayscale_image.shape)
# Out:
# (1440, 2560)

# %%
# cv2.imshow will display the image but it is allowed in gooogle colab

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=2560x1440>

# %%
cv2.imwrite('grayscale_image.jpg',grayscale_image)
# Out:
# True

# %%
type(grayscale_image)
# Out:
# numpy.ndarray
